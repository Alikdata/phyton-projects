# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'
,'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x2001a80d650>)

# %%
import pandas as pd

# %%
covid_df=pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
sorted_df=covid_df.sort_values('new_cases',ascending=True)

# %%
sorted_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 172  2020-06-20     -148.0        47.0    29875.0
# 0    2019-12-31        0.0         0.0        NaN
# 29   2020-01-29        0.0         0.0        NaN
# 30   2020-01-30        0.0         0.0        NaN
# 32   2020-02-01        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 88   2020-03-28     5959.0       971.0        NaN
# 89   2020-03-29     5974.0       887.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 87   2020-03-27     6153.0       660.0        NaN
# 82   2020-03-22     6557.0       795.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df.at[172,'new_cases']=330

# %%
covid_df.at[172,'new_cases']
# Out:
# 330.0

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df['total_cases']=covid_df.new_cases.cumsum()

# %%
covid_df['total_death']=covid_df.new_deaths.cumsum()

# %%
covid_df['total_tests']=covid_df.new_tests.cumsum()

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0    2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1    2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2    2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3    2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4    2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..          ...        ...         ...        ...          ...          ...
# 243  2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244  2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245  2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246  2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247  2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests
# 0            NaN
# 1            NaN
# ...

# %%
covid_df['positive_case']=covid_df.total_cases/covid_df.total_tests*100

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0    2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1    2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2    2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3    2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4    2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..          ...        ...         ...        ...          ...          ...
# 243  2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244  2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245  2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246  2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247  2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests  positive_case
# ...

# %%
covid_df=covid_df.drop(columns='positive_case')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0    2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1    2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2    2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3    2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4    2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..          ...        ...         ...        ...          ...          ...
# 243  2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244  2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245  2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246  2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247  2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests
# 0            NaN
# 1            NaN
# ...

# %%
covid_df['date']=pd.to_datetime(covid_df.date)

# %%
covid_df['year']=pd.DatetimeIndex(covid_df.date).year

# %%
covid_df['month']=pd.DatetimeIndex(covid_df.date).month

# %%
covid_df['day']=pd.DatetimeIndex(covid_df.date).day

# %%
covid_df['weekday']=pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0   2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1   2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2   2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3   2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4   2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..         ...        ...         ...        ...          ...          ...
# 243 2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244 2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245 2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246 2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247 2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests  year  month  day  weekday
# ...

# %%
total_months=covid_df.groupby('month')[['new_cases','new_deaths','new_tests']].sum()

# %%
total_months
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         8250.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
total_years=covid_df.groupby('year')[['new_cases','new_deaths','new_tests']].sum()

# %%
total_years
# Out:
#       new_cases  new_deaths  new_tests
# year
# 2019        0.0         0.0        0.0
# 2020   271993.0     35497.0  4279456.0

# %%
sorted_totals=total_months.sort_values('new_cases',ascending=False)

# %%
sorted_totals
# Out:
#        new_cases  new_deaths  new_tests
# month
# 4       101852.0     16091.0   419591.0
# 3       100851.0     11570.0        0.0
# 5        29073.0      5658.0  1078720.0
# 8        21060.0       345.0  1098704.0
# 6         8250.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 9         3297.0        20.0    54395.0
# 2          885.0        21.0        0.0
# 1            3.0         0.0        0.0
# 12           0.0         0.0        0.0

# %%
total_august=covid_df[covid_df.month==8]

# %%
total_august
# Out:
#           date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 214 2020-08-01      379.0         9.0    31905.0     248015.0      35141.0
# 215 2020-08-02      295.0         5.0    24496.0     248310.0      35146.0
# 216 2020-08-03      238.0         8.0    13467.0     248548.0      35154.0
# 217 2020-08-04      159.0        12.0    23491.0     248707.0      35166.0
# 218 2020-08-05      190.0         5.0    29739.0     248897.0      35171.0
# 219 2020-08-06      384.0        10.0    32169.0     249281.0      35181.0
# 220 2020-08-07      401.0         6.0    30392.0     249682.0      35187.0
# 221 2020-08-08      552.0         3.0    26631.0     250234.0      35190.0
# 222 2020-08-09      347.0        13.0    22773.0     250581.0      35203.0
# 223 2020-08-10      463.0         2.0    10904.0     251044.0      35205.0
# 224 2020-08-11      259.0         4.0    22063.0     251303.0      35209.0
# ...

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0   2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1   2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2   2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3   2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4   2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..         ...        ...         ...        ...          ...          ...
# 243 2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244 2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245 2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246 2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247 2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests  year  month  day  weekday
# ...

# %%
sundays_df=covid_df[covid_df.weekday==6][['new_cases','new_deaths','new_tests']]

# %%
sundays_df
# Out:
#      new_cases  new_deaths  new_tests
# 5          0.0         0.0        NaN
# 12         0.0         0.0        NaN
# 19         0.0         0.0        NaN
# 26         0.0         0.0        NaN
# 33         0.0         0.0        NaN
# 40         0.0         0.0        NaN
# 47         0.0         0.0        NaN
# 54        62.0         2.0        NaN
# 61       240.0         8.0        NaN
# 68      1247.0        36.0        NaN
# 75      3497.0       173.0        NaN
# 82      6557.0       795.0        NaN
# 89      5974.0       887.0        NaN
# 96      4805.0       681.0        NaN
# 103     4694.0       619.0        NaN
# 110     3491.0       480.0        NaN
# 117     2357.0       415.0    24113.0
# 124     1900.0       474.0    27047.0
# 131     1083.0       194.0    31384.0
# 138      875.0       153.0    33505.0
# 145      669.0       119.0    34206.0
# 152      416.0       111.0    28948.0
# 159      270.0        72.0    27894.0
# 166      346.0        78.0    29545.0
# ...

# %%
sundays_df=covid_df[covid_df.weekday==6][['new_cases','new_deaths','new_tests']].mean()

# %%
sundays_df
# Out:
# new_cases      1247.257143
# new_deaths      159.457143
# new_tests     28588.105263
# dtype: float64

# %%
days_df=covid_df[covid_df.weekday==1][['new_cases','new_deaths','new_tests']].mean()

# %%
days_df
# Out:
# new_cases       918.638889
# new_deaths      129.944444
# new_tests     31166.900000
# dtype: float64

# %%
octaber_mean=covid_df[covid_df.month==9][['new_cases','new_deaths','new_tests']].mean()

# %%
december_mean
# Out:
# new_cases      1099.000000
# new_deaths        6.666667
# new_tests     54395.000000
# dtype: float64

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0   2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1   2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2   2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3   2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4   2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..         ...        ...         ...        ...          ...          ...
# 243 2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244 2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245 2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246 2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247 2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests  year  month  day  weekday
# ...

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv', 
            'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x20020616390>)

# %%
locations_df=pd.read_csv('locations.csv')

# %%
locations_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
locations_df[locations_df.location=="italy"]
# Out:
# Empty DataFrame
# Columns: [location, continent, population, life_expectancy, hospital_beds_per_thousand, gdp_per_capita]
# Index: []

# %%
covid_df['location']='italy'

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0   2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1   2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2   2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3   2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4   2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..         ...        ...         ...        ...          ...          ...
# 243 2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244 2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245 2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246 2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247 2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests  year  month  day  weekday location
# ...

# %%
merged_df=covid_df.merge(locations_df,on='location')

# %%
merged_df
# Out:
# Empty DataFrame
# Columns: [date, new_cases, new_deaths, new_tests, total_cases, total_death, total_tests, year, month, day, weekday, location, continent, population, life_expectancy, hospital_beds_per_thousand, gdp_per_capita]
# Index: []

# %%
result_df=merged_df[['location','new_cases','new_deaths','new_tests','total_cases','total_death','total_tests','month','day',]]

# %%
result_df
# Out:
# Empty DataFrame
# Columns: [location, new_cases, new_deaths, new_tests, total_cases, total_death, total_tests, month, day]
# Index: []

# %%
result_df.to_csv('results.csv',index=None)

# %%
merged_df
# Out:
# Empty DataFrame
# Columns: [date, new_cases, new_deaths, new_tests, total_cases, total_death, total_tests, year, month, day, weekday, location, continent, population, life_expectancy, hospital_beds_per_thousand, gdp_per_capita]
# Index: []

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  total_cases  total_death  \
# 0   2019-12-31        0.0         0.0        NaN          0.0          0.0
# 1   2020-01-01        0.0         0.0        NaN          0.0          0.0
# 2   2020-01-02        0.0         0.0        NaN          0.0          0.0
# 3   2020-01-03        0.0         0.0        NaN          0.0          0.0
# 4   2020-01-04        0.0         0.0        NaN          0.0          0.0
# ..         ...        ...         ...        ...          ...          ...
# 243 2020-08-30     1444.0         1.0    53541.0     267331.0      35473.0
# 244 2020-08-31     1365.0         4.0    42583.0     268696.0      35477.0
# 245 2020-09-01      996.0         6.0    54395.0     269692.0      35483.0
# 246 2020-09-02      975.0         8.0        NaN     270667.0      35491.0
# 247 2020-09-03     1326.0         6.0        NaN     271993.0      35497.0
#
#      total_tests  year  month  day  weekday location
# ...

# %%
months_df=covid_df.groupby('month')[['total_cases','total_death','total_tests']].sum()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
months_df.plot()
# Out:
# <Axes: xlabel='month'>
