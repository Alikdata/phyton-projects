# %%
import pandas as pd
import numpy as np
import seaborn as np

# %%
bike_sales_df=pd.read_excel(r"C:\Users\user\Downloads\projects.xlsx","bike_sales")

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
bike_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108374 entries, 0 to 108373
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              62322 non-null  datetime64[ns]
#  1   Customer_Age      62322 non-null  float64
#  2   Customer_Gender   62322 non-null  object
#  3   Country           62322 non-null  object
#  4   State             62322 non-null  object
#  5   Product_Category  62322 non-null  object
#  6   Sub_Category      62322 non-null  object
#  7   Product           62322 non-null  object
#  8   Order_Quantity    62322 non-null  float64
#  9   Unit_Cost         62322 non-null  float64
#  10  Unit_Price        62322 non-null  float64
#  11  Profit            62322 non-null  float64
#  12  Cost              62322 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 10.7+ MB

# %%
bike_sales_df.describe()
# Out:
#        Customer_Age  Order_Quantity     Unit_Cost    Unit_Price        Profit  \
# count  62322.000000    62322.000000  62322.000000  62322.000000  62322.000000
# mean      35.989089       15.079811      5.070088     12.822149     89.205401
# std       11.384345        8.726795      7.386322     19.844873    137.577824
# min       17.000000        1.000000      1.000000      2.000000     -5.000000
# 25%       27.000000        7.000000      2.000000      5.000000     15.000000
# 50%       35.000000       15.000000      2.000000      5.000000     41.000000
# 75%       44.000000       23.000000      7.000000     10.000000     85.000000
# max       87.000000       32.000000     59.000000    159.000000   2214.000000
#
#                Cost
# count  62322.000000
# mean      70.041847
# std       94.995468
# min        1.000000
# 25%       16.000000
# 50%       34.000000
# 75%       80.000000
# max     1350.000000

# %%
bike_sales_df.shape
# Out:
# (108374, 13)

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
profit_df=bike_sales_df[['Country','Profit']]

# %%
profit_df
# Out:
#           Country  Profit
# 0          Canada   590.0
# 1          Canada   590.0
# 2       Australia  1366.0
# 3       Australia  1188.0
# 4       Australia   238.0
# ...           ...     ...
# 108369     France    10.0
# 108370     France     8.0
# 108371     France     3.0
# 108372     France    10.0
# 108373     France     3.0
#
# [108374 rows x 2 columns]

# %%
profit_df.loc[5]
# Out:
# Country    Australia
# Profit         297.0
# Name: 5, dtype: object

# %%
profit_df.tail(10)
# Out:
#        Country  Profit
# 108364  France    40.0
# 108365  France    55.0
# 108366  France    12.0
# 108367  France    11.0
# 108368  France    13.0
# 108369  France    10.0
# 108370  France     8.0
# 108371  France     3.0
# 108372  France    10.0
# 108373  France     3.0

# %%
profit_df.head(10)
# Out:
#      Country  Profit
# 0     Canada   590.0
# 1     Canada   590.0
# 2  Australia  1366.0
# 3  Australia  1188.0
# 4  Australia   238.0
# 5  Australia   297.0
# 6  Australia   199.0
# 7  Australia   100.0
# 8  Australia  1096.0
# 9  Australia  1046.0

# %%
bike_sales_df.Profit.first_valid_index()
# Out:
# 0

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
bike_sales_df['Revenue']=bike_sales_df.Profit+bike_sales_df.Cost

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
country_profit=bike_sales_df[['Country','Revenue']]

# %%
country_profit
# Out:
#           Country  Revenue
# 0          Canada    950.0
# 1          Canada    950.0
# 2       Australia   2401.0
# 3       Australia   2088.0
# 4       Australia    418.0
# ...           ...      ...
# 108369     France     25.0
# 108370     France     21.0
# 108371     France      8.0
# 108372     France     25.0
# 108373     France      8.0
#
# [108374 rows x 2 columns]

# %%
country_profit.sort_values('Revenue',ascending=False).head(10)
# Out:
#             Country  Revenue
# 245          Canada   3564.0
# 182   United States   3528.0
# 90    United States   3528.0
# 244          Canada   3445.0
# 183   United States   3410.0
# 95          Germany   3236.0
# 327  United Kingdom   3226.0
# 339          Canada   3208.0
# 101   United States   3175.0
# 91    United States   3175.0

# %%
country_profit.sort_values('Revenue',ascending=False).tail(10)
# Out:
#       Country  Revenue
# 74494     NaN      NaN
# 74495     NaN      NaN
# 74496     NaN      NaN
# 74497     NaN      NaN
# 74498     NaN      NaN
# 74499     NaN      NaN
# 74500     NaN      NaN
# 74501     NaN      NaN
# 74502     NaN      NaN
# 74503     NaN      NaN

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
bike_sales_df['date']=pd.to_datetime(bike_sales_df.Date)

# %%
bike_sales_df['year']=pd.DatetimeIndex(bike_sales_df.Date).year

# %%
bike_sales_df['month']=pd.DatetimeIndex(bike_sales_df.Date).month

# %%
bike_sales_df['weekday']=pd.DatetimeIndex(bike_sales_df.Date).weekday

# %%
bike_sales_df['day']=pd.DatetimeIndex(bike_sales_df.Date).day

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
canada_df=bike_sales_df[bike_sales_df.Country=='Canada']

# %%
canada_df[canada_df.month==8][['Country','month','Revenue']].sort_values('Revenue',ascending=False).head(10)
# Out:
#       Country  month  Revenue
# 42774  Canada    8.0   1579.0
# 42266  Canada    8.0   1579.0
# 42775  Canada    8.0   1579.0
# 42267  Canada    8.0   1525.0
# 273    Canada    8.0   1426.0
# 42411  Canada    8.0   1307.0
# 42410  Canada    8.0   1307.0
# 42106  Canada    8.0   1307.0
# 43116  Canada    8.0   1252.0
# 272    Canada    8.0   1188.0

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
france_df=bike_sales_df[bike_sales_df.Country=='France']

# %%
france_df.groupby('year')[['Country','Revenue']].max()
# Out:
#        Country  Revenue
# year
# 2013.0  France   2957.0
# 2014.0  France   1670.0
# 2015.0  France   2851.0
# 2016.0  France   1775.0

# %%
bike_sales_df.groupby(['Country','Product_Category'])[[ 'Product_Category','Revenue']].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7564\1020949112.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bike_sales_df.groupby(['Country','Product_Category'])[[ 'Product_Category','Revenue']].mean()
#                                     Revenue
# Country        Product_Category
# Australia      Accessories       154.322902
#                Clothing          119.536730
# Canada         Accessories       174.232900
#                Clothing          137.825000
# France         Accessories       146.716125
#                Clothing          117.320675
# Germany        Accessories       170.760409
#                Clothing          122.629964
# United Kingdom Accessories       159.543787
#                Clothing          134.246970
# United States  Accessories       162.778709
# ...

# %%
bike_sales_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
canada_2014_df=bike_sales_df[bike_sales_df.Country=='Canada']

# %%
result_df=canada_2014_df[canada_2014_df.year==2013][['year','month','Country','Revenue']].sort_values('Revenue',ascending=False).head(10)

# %%
result_df.Revenue.plot(kind='bar')
# Out:
# <Axes: >
