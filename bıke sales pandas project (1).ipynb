# %%
import pandas as pd

# %%
bike_df=pd.read_excel(r"C:\Users\user\Desktop\Yeni Microsoft Excel Worksheet.xlsx")

# %%
bike_df
# Out:
#           Date  Customer_Age  Age_group  Gender    Country             State  \
# 0   2013-11-26            19    adultry    Male     Canada  British Columbia
# 1   2015-11-26            19    adultry    Male     Canada  British Columbia
# 2   2014-03-23            49  midle_age    Male  Australia   New South Wales
# 3   2016-03-23            49  midle_age    Male  Australia   New South Wales
# 4   2014-05-15            47  midle_age  Female  Australia   New South Wales
# ..         ...           ...        ...     ...        ...               ...
# 195 2016-01-01            24    adultry    Male  Australia   New South Wales
# 196 2014-03-01            24    adultry  Female  Australia          Victoria
# 197 2016-03-01            24    adultry  Female  Australia          Victoria
# 198 2014-06-12            26      young    Male  Australia   New South Wales
# 199 2016-06-12            26      young    Male  Australia   New South Wales
#
# ...

# %%
#some basic info of given data:

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              200 non-null    datetime64[ns]
#  1   Customer_Age      200 non-null    int64
#  2   Age_group         200 non-null    object
#  3   Gender            200 non-null    object
#  4   Country           200 non-null    object
#  5   State             200 non-null    object
#  6   Product_Category  200 non-null    object
#  7   Sub_Category      200 non-null    object
#  8   Product           200 non-null    object
#  9   Order_Quantity    200 non-null    int64
#  10  Unit_Cost         200 non-null    int64
#  11  Unit_Price        200 non-null    int64
#  12  Profit            200 non-null    int64
#  13  Cost              200 non-null    int64
#  14  Revenue           200 non-null    int64
# dtypes: datetime64[ns](1), int64(7), object(7)
# memory usage: 23.6+ KB

# %%
bike_df.describe()
# Out:
#        Customer_Age  Order_Quantity  Unit_Cost  Unit_Price     Profit  \
# count    200.000000      200.000000      200.0       200.0   200.0000
# mean      38.990000        8.570000       45.0       120.0   553.3950
# std       12.215399        7.359751        0.0         0.0   502.2115
# min       19.000000        1.000000       45.0       120.0    49.0000
# 25%       29.000000        3.000000       45.0       120.0   199.7500
# 50%       38.000000        7.000000       45.0       120.0   411.5000
# 75%       47.250000       10.000000       45.0       120.0   701.7500
# max       87.000000       30.000000       45.0       120.0  2178.0000
#
#               Cost      Revenue
# count   200.000000   200.000000
# mean    385.650000   939.045000
# std     331.188779   829.046418
# min      45.000000    94.000000
# 25%     135.000000   353.000000
# 50%     315.000000   713.000000
# 75%     450.000000  1176.000000
# max    1350.000000  3528.000000

# %%
#retrieving some data:

# %%
bike_df.loc[100]
# Out:
# Date                2014-05-11 00:00:00
# Customer_Age                         32
# Age_group                         young
# Gender                             Male
# Country                   United States
# State                        California
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                       26
# Unit_Cost                            45
# Unit_Price                          120
# Profit                             1888
# Cost                               1170
# Revenue                            3058
# Name: 100, dtype: object

# %%
bike_df.at[100,"Cost"]
# Out:
# 1170

# %%
revenue_df=bike_df[["Country","Date","Revenue"]]

# %%
revenue_df.sort_values('Revenue',ascending=False)
# Out:
#            Country       Date  Revenue
# 90   United States 2014-02-12     3528
# 182  United States 2014-01-17     3528
# 183  United States 2016-01-17     3410
# 95         Germany 2015-09-23     3236
# 91   United States 2016-02-12     3175
# ..             ...        ...      ...
# 49         Germany 2015-08-07       98
# 119      Australia 2015-10-27       95
# 86   United States 2014-02-04       94
# 173  United States 2016-02-27       94
# 97   United States 2015-09-20       94
#
# [200 rows x 3 columns]

# %%
bike_df.sample(100)
# Out:
#           Date  Customer_Age  Age_group  Gender        Country  \
# 93  2016-05-17            46  midle_age    Male  United States
# 141 2016-06-06            32      young  Female         France
# 169 2015-07-31            29      young  Female  United States
# 73  2016-05-30            38  midle_age  Female  United States
# 173 2016-02-27            55        old  Female  United States
# ..         ...           ...        ...     ...            ...
# 101 2016-05-11            32      young    Male  United States
# 27  2015-12-26            49  midle_age    Male         Canada
# 183 2016-01-17            53  midle_age  Female  United States
# 6   2014-05-22            47  midle_age  Female      Australia
# 13  2015-07-15            34      young    Male      Australia
#
#                 State Product_Category Sub_Category              Product  \
# 93         California      Accessories   Bike Racks  Hitch Rack - 4-Bike
# ...

# %%
bike_df
# Out:
#           Date  Customer_Age  Age_group  Gender    Country             State  \
# 0   2013-11-26            19    adultry    Male     Canada  British Columbia
# 1   2015-11-26            19    adultry    Male     Canada  British Columbia
# 2   2014-03-23            49  midle_age    Male  Australia   New South Wales
# 3   2016-03-23            49  midle_age    Male  Australia   New South Wales
# 4   2014-05-15            47  midle_age  Female  Australia   New South Wales
# ..         ...           ...        ...     ...        ...               ...
# 195 2016-01-01            24    adultry    Male  Australia   New South Wales
# 196 2014-03-01            24    adultry  Female  Australia          Victoria
# 197 2016-03-01            24    adultry  Female  Australia          Victoria
# 198 2014-06-12            26      young    Male  Australia   New South Wales
# 199 2016-06-12            26      young    Male  Australia   New South Wales
#
# ...

# %%
bike_df.drop(columns="Revenue",inplace=True)

# %%
bike_df
# Out:
#           Date  Customer_Age  Age_group  Gender    Country             State  \
# 0   2013-11-26            19    adultry    Male     Canada  British Columbia
# 1   2015-11-26            19    adultry    Male     Canada  British Columbia
# 2   2014-03-23            49  midle_age    Male  Australia   New South Wales
# 3   2016-03-23            49  midle_age    Male  Australia   New South Wales
# 4   2014-05-15            47  midle_age  Female  Australia   New South Wales
# ..         ...           ...        ...     ...        ...               ...
# 195 2016-01-01            24    adultry    Male  Australia   New South Wales
# 196 2014-03-01            24    adultry  Female  Australia          Victoria
# 197 2016-03-01            24    adultry  Female  Australia          Victoria
# 198 2014-06-12            26      young    Male  Australia   New South Wales
# 199 2016-06-12            26      young    Male  Australia   New South Wales
#
# ...

# %%
bike_df["Revenue"]=bike_df.Cost+bike_df.Profit

# %%
bike_df
# Out:
#           Date  Customer_Age  Age_group  Gender    Country             State  \
# 0   2013-11-26            19    adultry    Male     Canada  British Columbia
# 1   2015-11-26            19    adultry    Male     Canada  British Columbia
# 2   2014-03-23            49  midle_age    Male  Australia   New South Wales
# 3   2016-03-23            49  midle_age    Male  Australia   New South Wales
# 4   2014-05-15            47  midle_age  Female  Australia   New South Wales
# ..         ...           ...        ...     ...        ...               ...
# 195 2016-01-01            24    adultry    Male  Australia   New South Wales
# 196 2014-03-01            24    adultry  Female  Australia          Victoria
# 197 2016-03-01            24    adultry  Female  Australia          Victoria
# 198 2014-06-12            26      young    Male  Australia   New South Wales
# 199 2016-06-12            26      young    Male  Australia   New South Wales
#
# ...

# %%
higher_revenue=bike_df[bike_df.Revenue>=2000]

# %%
higher_revenue.sort_values("Revenue",ascending=False).head(10)
# Out:
#           Date  Customer_Age  Age_group  Gender        Country  \
# 90  2014-02-12            46  midle_age    Male  United States
# 182 2014-01-17            53  midle_age  Female  United States
# 183 2016-01-17            53  midle_age  Female  United States
# 95  2015-09-23            41  midle_age  Female        Germany
# 101 2016-05-11            32      young    Male  United States
# 91  2016-02-12            46  midle_age    Male  United States
# 94  2013-09-23            41  midle_age  Female        Germany
# 100 2014-05-11            32      young    Male  United States
# 36  2013-11-11            34      young    Male         Canada
# 52  2013-08-17            43  midle_age  Female         France
#
#                 State Product_Category Sub_Category              Product  \
# 90         California      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 182        California      Accessories   Bike Racks  Hitch Rack - 4-Bike
# ...

# %%
#working with dates

# %%
bike_df["Date"]=pd.to_datetime(bike_df.Date)

# %%
bike_df["year"]=pd.DatetimeIndex(bike_df.Date).year
bike_df["month"]=pd.DatetimeIndex(bike_df.Date).month
bike_df["day"]=pd.DatetimeIndex(bike_df.Date).day
bike_df["weekday"]=pd.DatetimeIndex(bike_df.Date).weekday

# %%
bike_df
# Out:
#           Date  Customer_Age  Age_group  Gender    Country             State  \
# 0   2013-11-26            19    adultry    Male     Canada  British Columbia
# 1   2015-11-26            19    adultry    Male     Canada  British Columbia
# 2   2014-03-23            49  midle_age    Male  Australia   New South Wales
# 3   2016-03-23            49  midle_age    Male  Australia   New South Wales
# 4   2014-05-15            47  midle_age  Female  Australia   New South Wales
# ..         ...           ...        ...     ...        ...               ...
# 195 2016-01-01            24    adultry    Male  Australia   New South Wales
# 196 2014-03-01            24    adultry  Female  Australia          Victoria
# 197 2016-03-01            24    adultry  Female  Australia          Victoria
# 198 2014-06-12            26      young    Male  Australia   New South Wales
# 199 2016-06-12            26      young    Male  Australia   New South Wales
#
# ...

# %%
bike_df_may=bike_df[bike_df.month==5][["Country","Product_Category","Revenue"]]

# %%
bike_df_may.sort_values("Revenue",ascending=True)
# Out:
#            Country Product_Category  Revenue
# 123  United States      Accessories      118
# 122  United States      Accessories      118
# 106  United States      Accessories      118
# 7        Australia      Accessories      190
# 139        Germany      Accessories      223
# 93   United States      Accessories      235
# 72   United States      Accessories      235
# 73   United States      Accessories      235
# 138        Germany      Accessories      335
# 107  United States      Accessories      353
# 6        Australia      Accessories      379
# 160      Australia      Accessories      418
# 4        Australia      Accessories      418
# 5        Australia      Accessories      522
# 92   United States      Accessories      588
# 161      Australia      Accessories      626
# 184  United States      Accessories      706
# 185  United States      Accessories      706
# 20          Canada      Accessories      713
# 21          Canada      Accessories      950
# ...

# %%
#Groupping and Agregattion

# %%
bike_df
# Out:
#           Date  Customer_Age  Age_group  Gender    Country             State  \
# 0   2013-11-26            19    adultry    Male     Canada  British Columbia
# 1   2015-11-26            19    adultry    Male     Canada  British Columbia
# 2   2014-03-23            49  midle_age    Male  Australia   New South Wales
# 3   2016-03-23            49  midle_age    Male  Australia   New South Wales
# 4   2014-05-15            47  midle_age  Female  Australia   New South Wales
# ..         ...           ...        ...     ...        ...               ...
# 195 2016-01-01            24    adultry    Male  Australia   New South Wales
# 196 2014-03-01            24    adultry  Female  Australia          Victoria
# 197 2016-03-01            24    adultry  Female  Australia          Victoria
# 198 2014-06-12            26      young    Male  Australia   New South Wales
# 199 2016-06-12            26      young    Male  Australia   New South Wales
#
# ...

# %%
group_country=bike_df.groupby("Country")[["Order_Quantity","Cost","Profit","Revenue"]].sum()

# %%
group_country.sort_values("Revenue",ascending=True)
# Out:
#                 Order_Quantity   Cost  Profit  Revenue
# Country
# United Kingdom              36   1620    2527     4147
# Germany                     90   4050    5653     9703
# France                      99   4455    5879    10334
# Australia                  262  11790   14508    26298
# Canada                     321  14445   23691    38136
# United States              906  40770   58421    99191
